# %%
# !python --version
# Out:
# Python 3.12.8

# %%
from qiskit import qasm, qasm2,qasm3
from qiskit.circuit import QuantumCircuit
from qiskit.transpiler import generate_preset_pass_manager
from qiskit_ibm_runtime import QiskitRuntimeService

import numpy as np
from matplotlib import pyplot as plt

from qiskit.visualization import plot_histogram
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 4
#       2 from qiskit.circuit import QuantumCircuit
#       3 from qiskit.transpiler import generate_preset_pass_manager
# ----> 4 from qiskit_ibm_runtime import QiskitRuntimeService
#       6 import numpy as np
#       7 from matplotlib import pyplot as plt
#
# File c:\Users\Masashi Takahashi\Documents\Code\Python_tests\qiskit_tests\QAOA_IBM_runtime\Lib\site-packages\qiskit_ibm_runtime\__init__.py:205
#     202 import logging
#     203 import warnings
# --> 205 from .qiskit_runtime_service import QiskitRuntimeService
#     206 from .ibm_backend import IBMBackend
#     207 from .runtime_job import RuntimeJob
#
# File c:\Users\Masashi Takahashi\Documents\Code\Python_tests\qiskit_tests\QAOA_IBM_runtime\Lib\site-packages\qiskit_ibm_runtime\qiskit_runtime_service.py:27
# ...

# %%
shots = 10000
backend = QiskitRuntimeService().backend("some-backend")
circ = qasm3.load('qasm_circs/P2_swift_rise.qasm')
circ.measure_all()
circ = circ.decompose(reps=3)
compile = transpile(circ,backend=backend,optimization_level=3)
compile.draw("mpl")
# Out:
# ---------------------------------------------------------------------------
# MissingOptionalLibraryError               Traceback (most recent call last)
# Cell In[18], line 3
#       1 shots = 10000
#       2 backend = AerSimulator()
# ----> 3 circ = qasm3.load('qasm_circs/P2_swift_rise.qasm')
#       4 circ.measure_all()
#       5 circ = circ.decompose(reps=3)
#
# File c:\Users\Masashi Takahashi\Documents\Code\Python_tests\qiskit_tests\QAOA_IBM_runtime\Lib\site-packages\qiskit\utils\lazy_tester.py:148, in LazyDependencyManager.require_in_call.<locals>.decorator.<locals>.out(*args, **kwargs)
#     146 @functools.wraps(function)
#     147 def out(*args, **kwargs):
# --> 148     self.require_now(feature)
#     149     return function(*args, **kwargs)
#
# File c:\Users\Masashi Takahashi\Documents\Code\Python_tests\qiskit_tests\QAOA_IBM_runtime\Lib\site-packages\qiskit\utils\lazy_tester.py:221, in LazyDependencyManager.require_now(self, feature)
#     219 if self:
#     220     return
# ...

# %%
job = backend.run(compile,shots=shots)
res = job.result()
counts = res.get_counts()
plot_histogram(counts)
